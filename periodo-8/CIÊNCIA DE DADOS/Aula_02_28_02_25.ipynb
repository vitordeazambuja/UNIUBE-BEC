# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **### Aula 02 - Ciência de Dados**
#
# Prof. Clênio Silva
#
# Explorando um conjunto de dados pequeno de vendas por ano.

# %%
df = pd.read_csv('sample_data/dataset1.csv', delimiter=';')

# %%
df.head()
# Out:
#     Ano  Vendas
# 0  2020    1500
# 1  2021    1800
# 2  2022    2100

# %%
df.describe()
# Out:
#           Ano  Vendas
# count     3.0     3.0
# mean   2021.0  1800.0
# std       1.0   300.0
# min    2020.0  1500.0
# 25%    2020.5  1650.0
# 50%    2021.0  1800.0
# 75%    2021.5  1950.0
# max    2022.0  2100.0

# %%
plt.plot(df['Ano'], df['Vendas'], marker='o')
plt.title('Vendas anuais')
plt.xlabel('Ano')
plt.ylabel('vendas')
plt.grid(True)
plt.show()
